# %% [markdown]
# # Libraries

# %%
import sys
sys.path.append("../")

# %%
# for working with data
import pandas as pd
import numpy as np
from src.data_exploration import explore_functions as explr

# for visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Data

# %%
taiwan = pd.read_excel("../data/taiwan_default_payments.xls", header=1)
taiwan
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
taiwan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
explr.multi_features_explore(taiwan)
# Out:
# index                       dtype nonnull %nonnull nan %nan nunique  \
# ID                          int64   30000      1.0   0  0.0   30000
# LIMIT_BAL                   int64   30000      1.0   0  0.0      81
# SEX                         int64   30000      1.0   0  0.0       2
# EDUCATION                   int64   30000      1.0   0  0.0       7
# MARRIAGE                    int64   30000      1.0   0  0.0       4
# AGE                         int64   30000      1.0   0  0.0      56
# PAY_0                       int64   30000      1.0   0  0.0      11
# PAY_2                       int64   30000      1.0   0  0.0      11
# PAY_3                       int64   30000      1.0   0  0.0      11
# PAY_4                       int64   30000      1.0   0  0.0      11
# PAY_5                       int64   30000      1.0   0  0.0      10
# PAY_6                       int64   30000      1.0   0  0.0      10
# BILL_AMT1                   int64   30000      1.0   0  0.0   22723
# ...

# %%
def check_balance(data, target, chart_types="pie", normalize=True, positive_target=0):
    target_counts = data[target].value_counts()
    target_counts.index = ["non-default" if i==positive_target else "default" for i in target_counts.index] 
    # sns.barplot(x=target_counts.index, y=target_counts.values, hue=target_counts.index)
    if chart_types == "pie":
        plt.pie(target_counts.values, labels=target_counts.index, normalize=normalize, startangle=90,
            autopct="%1.1f%%", explode=[0, 0.1])
    elif chart_types == "bar":
        sns.barplot(x=target_counts.index, y=target_counts.values, hue=target_counts.index, palette="tab10")
        plt.xlabel("Targets")
    plt.title("Distribution of Targets")
    plt.show()

check_balance(taiwan, "default payment next month", chart_types="pie")

# %%
german_opened = open("../data/german.data")
german = german_opened.readlines()
german = [x.replace('\n', '').split() for x in german]

# %%
german_df = pd.DataFrame(german)
check_balance(german_df, 20, positive_target='1')

# %%
coursera_train = pd.read_csv("../data/coursera_data/train.csv")
coursera_train
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0       I38PQUQS96   56   85994       50587          520              80
# 1       HPSK72WA7R   69   50432      124440          458              15
# 2       C1OZ6DPJ8Y   46   84208      129188          451              26
# 3       V2KKSFM3UN   32   31713       44799          743               0
# 4       EY08JDHTZP   60   20437        9139          633               8
# ...            ...  ...     ...         ...          ...             ...
# 255342  8C6S86ESGC   19   37979      210682          541             109
# 255343  98R4KDHNND   32   51953      189899          511              14
# 255344  XQK1UUUNGP   56   84820      208294          597              70
# 255345  JAO28CPL4H   42   85109       60575          809              40
# 255346  ZTH91CGL0B   62   22418       18481          636             113
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# ...

# %%
explr.multi_features_explore(coursera_train)
# Out:
# index             dtype nonnull %nonnull nan %nan nunique nunique_nan  \
# LoanID           object  255347      1.0   0  0.0  255347      255347
# Age               int64  255347      1.0   0  0.0      52          52
# Income            int64  255347      1.0   0  0.0  114620      114620
# LoanAmount        int64  255347      1.0   0  0.0  158729      158729
# CreditScore       int64  255347      1.0   0  0.0     550         550
# MonthsEmployed    int64  255347      1.0   0  0.0     120         120
# NumCreditLines    int64  255347      1.0   0  0.0       4           4
# InterestRate    float64  255347      1.0   0  0.0    2301        2301
# LoanTerm          int64  255347      1.0   0  0.0       5           5
# DTIRatio        float64  255347      1.0   0  0.0      81          81
# Education        object  255347      1.0   0  0.0       4           4
# EmploymentType   object  255347      1.0   0  0.0       4           4
# ...

# %%
check_balance(coursera_train, 'Default')

# %%
explr.check_nan(coursera_train)
# Out:
# Empty DataFrame
# Columns: [nan, %nan]
# Index: []

# %%
crd = pd.read_csv("../data/credit_risk_dataset.csv")
crd
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
explr.check_nan(crd)
# Out:
#                     nan      %nan
# loan_int_rate      3116  9.563856
# person_emp_length   895  2.747000

# %%
check_balance(crd, "loan_status")

# %%
loan_full = pd.read_csv("../data/loans_full_schema.csv")
loan_full
# Out:
#                     emp_title  emp_length state homeownership  annual_income  \
# 0     global config engineer          3.0    NJ      MORTGAGE        90000.0
# 1      warehouse office clerk        10.0    HI          RENT        40000.0
# 2                    assembly         3.0    WI          RENT        40000.0
# 3            customer service         1.0    PA          RENT        30000.0
# 4        security supervisor         10.0    CA          RENT        35000.0
# ...                       ...         ...   ...           ...            ...
# 9995                   owner         10.0    TX          RENT       108000.0
# 9996                 director         8.0    PA      MORTGAGE       121000.0
# 9997                toolmaker        10.0    CT      MORTGAGE        67000.0
# 9998                  manager         1.0    WI      MORTGAGE        80000.0
# 9999       operations analyst         3.0    CT          RENT        66000.0
#
# ...

# %%
explr.check_nan(loan_full)
# Out:
#                                    nan   %nan
# verification_income_joint         8545  85.45
# debt_to_income_joint              8505  85.05
# annual_income_joint               8505  85.05
# months_since_90d_late             7715  77.15
# months_since_last_delinq          5658  56.58
# months_since_last_credit_inquiry  1271  12.71
# emp_title                          833   8.33
# emp_length                         817   8.17
# num_accounts_120d_past_due         318   3.18
# debt_to_income                      24   0.24
